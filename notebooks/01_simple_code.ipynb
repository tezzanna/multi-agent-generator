# %% [markdown]
# # Простой скрипт

# %% [markdown]
# ## Зависимости

# %%
import os
from fastapi import FastAPI
from fastapi.staticfiles import StaticFiles

from agents import (
    AgentContext,
    PlannerAgent,
    DDDAnalystAgent,
    TestEngineerAgent,
    DeveloperAgent,
    ReviewerAgent,
    BuilderAgent
)

# %% [markdown]
# ## Промпт пользователя

# %%
prompt = "Создай веб-приложение, на котором написано `Добро пожаловать` на главной странице"

# %% [markdown]
# ## Реализация агентов

# %%
# to-do

# %% [markdown]
# ## Запуск работы мультиагентной системы

# %%
# to-do

# %% [markdown]
# ```
# Полученная ссылка на веб-приложение: http://localhost:8000
# ```
